# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['PYTHONPATH'] = '/env/python'

# %%
# prompt: in thư mục hiện tại

import os
print(os.getcwd())
# Out:
# /content

# %%
# %cd '/content/gdrive/My Drive/HCMUTE/XLAS/YOLO/train_yolov11n'
# Out:
# /content/gdrive/My Drive/HCMUTE/XLAS/YOLO/train_yolov11n

# %%
# %pip install "ultralytics<=8.3.130" supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.130 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.7/112.6 GB disk)

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")

# %%
model.train(data='../data.yaml', epochs=50)
# Out:
# Ultralytics 8.3.130 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model_predict = YOLO("runs/detect/train6/weights/last.pt")

# %%
from PIL import Image

# %%
image = Image.open("thanhLong.jpg")

# %%
result = model_predict.predict(image, conf=0.25)[0]
# Out:
# 0: 640x640 1 thanh_long, 11.3ms
# Speed: 3.8ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
import supervision as sv

detections = sv.Detections.from_ultralytics(result)

# %%
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

annotated_image = image.copy()
annotated_image = box_annotator.annotate(annotated_image, detections=detections)
annotated_image = label_annotator.annotate(annotated_image, detections=detections)

sv.plot_image(annotated_image, size=(10, 10))
